# %% [markdown]
# <a href="https://colab.research.google.com/github/DmtrRm/IAAC2024_tutorials/blob/main/data_gettingtoknow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the necessary packages

from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# reading the data

train = pd.read_csv("/content/train.csv", index_col=0)
metadata = pd.read_csv("/content/metadata.csv", index_col=0)

database = pd.concat([train,metadata])

print("metadata: ", "rows =", str(metadata.shape[0]),"columns =", str(metadata.shape[1]))
print("train: ", "rows =", str(train.shape[0]),"columns =", str(train.shape[1]))

print("database: ", "rows =", str(database.shape[0]),"columns =", str(database.shape[1]))
database.head()
# Out:
# metadata:  rows = 251 columns = 31
# train:  rows = 266266 columns = 4
# database:  rows = 266517 columns = 34
#    building_id         day  meter  meter_reading site_id  site_id_kaggle  \
# 0            2  2016-02-02  595.0          102.6     NaN             NaN
# 1            2  2016-02-02  207.0            0.3     NaN             NaN
# 2            2  2016-02-03  595.0           88.8     NaN             NaN
# 3            2  2016-02-03  207.0            0.1     NaN             NaN
# 4            2  2016-02-04  595.0           76.3     NaN             NaN
#
#   primaryspaceusage sub_primaryspaceusage  sqm  sqft  ...  yearbuilt  \
# 0               NaN                   NaN  NaN   NaN  ...        NaN
# 1               NaN                   NaN  NaN   NaN  ...        NaN
# 2               NaN                   NaN  NaN   NaN  ...        NaN
# 3               NaN                   NaN  NaN   NaN  ...        NaN
# 4               NaN                   NaN  NaN   NaN  ...        NaN
#
# ...

# %%
metadata.head()
# Out:
#      building_id  site_id  site_id_kaggle primaryspaceusage  \
# 136          432  Trapano           143.0         Education
# 137          416  Trapano           143.0         Education
# 138          436  Trapano           143.0         Education
# 139          441  Trapano           143.0         Education
# 140          442  Trapano           143.0         Education
#
#     sub_primaryspaceusage     sqm     sqft       lat       lng       timezone  \
# 136     College Classroom  4703.0  50623.0  51.51879 -0.134556  Europe/London
# 137     College Classroom   499.3   5374.0  51.51879 -0.134556  Europe/London
# 138     College Classroom  9061.0  97532.0  51.51879 -0.134556  Europe/London
# 139    College Laboratory  7579.0  81580.0  51.51879 -0.134556  Europe/London
# 140    College Laboratory  5295.0  56995.0  51.51879 -0.134556  Europe/London
#
#      ... yearbuilt date_opened  numberoffloors  occupants energystarscore  \
# ...

# %%
# segmenting the dataset

print(database.shape[1])

name =database[0:5]

name.head()
# Out:
# 34
#    building_id  chilledwater  date_opened  day  electricity  energystarscore  \
# 0          NaN           NaN          NaN  NaN          NaN              NaN
# 1          NaN           NaN          NaN  NaN          NaN              NaN
# 2          NaN           NaN          NaN  NaN          NaN              NaN
# 3          NaN           NaN          NaN  NaN          NaN              NaN
# 4          NaN           NaN          NaN  NaN          NaN              NaN
#
#    eui  gas  heatingtype  hotwater  ...  solar  source_eui  sqft  sqm  steam  \
# 0  NaN  NaN          NaN       NaN  ...    NaN         NaN   NaN  NaN    NaN
# 1  NaN  NaN          NaN       NaN  ...    NaN         NaN   NaN  NaN    NaN
# 2  NaN  NaN          NaN       NaN  ...    NaN         NaN   NaN  NaN    NaN
# 3  NaN  NaN          NaN       NaN  ...    NaN         NaN   NaN  NaN    NaN
# 4  NaN  NaN          NaN       NaN  ...    NaN         NaN   NaN  NaN    NaN
#
# ...
